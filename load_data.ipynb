# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %%
# Carpeta Base de Datos Faltantes _ X
# Carga de datos
## Por el momento todos los archivos no se encuentran disponibles para descargar

# %%
#Cargar archivo 1 (DISCO2-TR_EXP_ALUMNO_CONTROL.txt)
#Intenté estrategia whitespace pero hay columnas vacías y campos con espacios intermedios (falta1 y falta2)
#falta3 sí lee. Es un solo archivo de 3.08 GB (tarda muchísimo en leer)

#falta1 = pd.read_csv("/Volumes/PCT/CEMABE/BDfaltantes_X/DISCO2-TR_EXP_ALUMNO_CONTROL.txt", header=0, delim_whitespace=True, nrows=10)
#falta2 = pd.read_csv("/Volumes/PCT/CEMABE/BDfaltantes_X/DISCO2-TR_EXP_CUES_CONAFE_ALUMNO.txt", header=0, delim_whitespace=True, nrows=10)
#pd.read_csv("/Volumes/PCT/CEMABE/BDfaltantes_X/DISCO3-TR_EXP_CUES_ALUMNO.txt", sep='|', header=0, encoding='latin-1', nrows=10)

# %%
# Carpeta Centros_trabajo_X
# Carga de datos
## Por el momento todos los archivos no se encuentran disponibles para descargar

# %%
pd.read_csv("/Volumes/PCT/CEMABE/Centros_trabajo_X/TR_EXP_CENTRAB_CONTROL.txt", header=0, sep='|', encoding='latin-1', index_col=0)
# Out:
#            CLAVE_CT  ENT  MUN   LOC  AGEB  MZA  \
# ID_INM
# 48      01KJN0025Y1    1    5    34  004A    1
# 49      01KJN0258N1    1    5    58  004A  800
# 49      01KPR0025O1    1    5    58  004A  800
# 50      01KJN0116P1    1    5    87  0073  800
# 51      01KJN0024Z1    1    5   248  004A    6
# 52      01KJN0280P1    1    5   352  0054    6
# 53      01KJN0069V1    1    3    87  0026    1
# 54      01KJN0002N1    1    1   444  1231    1
# 55      01KPR0213H1    1    3   105  0026    2
# 55      01KJN0146J1    1    3   105  0026    2
# 55      01KTV0013I1    1    3   105  0026    2
# 56      01KTV0023P1    1    1   121  1180    4
# 56      01KPR0229I1    1    1   121  1180    4
# 57      01KJN0041P1    1    1   121  1180    7
# 58      01KJN0119M1    1    1   128  1759    7
# 59      01KJN0115Q1    1    1   135  1250    4
# 60      01KJN0054T1    1    1   170  1246    2
# 61      01KJN0004L1    1    1   292  1123    3
# 62      01KJN0206H1    1    1   296  1176   32
# ...

# %%
pd.read_csv("/Volumes/PCT/CEMABE/Centros_trabajo_X/TR_EXP_CUES_CENTRAB.txt", header=0, sep='|', encoding='latin-1')
# Out:
#         ENT  MUN  LOC  AGEB  MZA  ID_INM     CLAVE_CT  NIVEL  MODALIDAD  \
# 0         1    1    1  2723   19     523  01DPR0026D1      3          1
# 1         1    1    1  3825   16     524  01DJN0402Z2      2          1
# 2         1    1    1  3825   16     524  01DJN0400B1      2          1
# 3         1    1    1  3825   16     525  01DPR0703M2      3          1
# 4         1    1    1  3825   16     525  01DPR0688K1      3          1
# 5         1    1    1  3825   34     526  01DES0034F2      4          1
# 6         1    1    1  3825   34     526  01DES0034F1      4          1
# 7         1    1    1  2954   18     527  01DES0031I2      4          1
# 8         1    1    1  2954   18     527  01DES0031I1      4          1
# 9         1    1    1  2973    7     528  01DJN0328I1      2          1
# 10        1    1    1  2973    7     529  01DPR0072P1      3          1
# 11        1    1    1  2333   41     487  01ADG0127U4      9        NaN
# ...

# %%
pd.read_csv("/Volumes/PCT/CEMABE/Centros_trabajo_X/TR_EXP_CUES_CONAFE_INM_CT_LST.txt", header=0, sep='|', encoding='latin-1')
# Out:
#        ID_INM     CLAVE_CT          PA  \
# 0         165  01KJN0001O1  01KJN0001O
# 1          54  01KJN0002N1  01KJN0002N
# 2          61  01KJN0004L1  01KJN0004L
# 3         104  01KJN0010W1  01KJN0010W
# 4           1  01KJN0015R1  01KJN0015R
# 5         166  01KJN0016Q1  01KJN0016Q
# 6         134  01KJN0019N1  01KJN0019N
# 7          20  01KJN0020C1  01KJN0020C
# 8          36  01KJN0021B1  01KJN0021B
# 9          51  01KJN0024Z1  01KJN0024Z
# 10         48  01KJN0025Y1  01KJN0025Y
# 11         80  01KJN0026X1  01KJN0026X
# 12         90  01KJN0027W1  01KJN0027W
# 13        168  01KJN0032H1  01KJN0032H
# 14          2  01KJN0033G1  01KJN0033G
# 15        105  01KJN0034F1  01KJN0034F
# 16        152  01KJN0036D1  01KJN0036D
# 17        156  01KJN0039A1  01KJN0039A
# 18         57  01KJN0041P1  01KJN0041P
# 19        150  01KJN0044M1  01KJN0044M
# 20        106  01KJN0045L1  01KJN0045L
# 21        158  01KJN0046K1  01KJN0046K
# 22         11  01KJN0048I1  01KJN0048I
# ...

# %%
pd.read_csv("/Volumes/PCT/CEMABE/Centros_trabajo_X/TR_EXP_REL_GRADOS_GRUPOS_CT.txt", header=0, sep='|', encoding='latin-1')
# Out:
#             CLAVE_CT GRADO GRUPO  MULTIGRADO
# 0        01DPR0021I2     3     A           0
# 1        01DPR0022H2     5     A           0
# 2        01DPR0022H2     6     A           0
# 3        01DPR0022H2     4     A           0
# 4        01DPR0022H2     3     A           0
# 5        01DPR0022H2     2     A           0
# 6        01DPR0023G2     5     B           0
# 7        01DPR0023G2     5     A           0
# 8        01DPR0023G2     6     A           0
# 9        01DPR0023G2     6     B           0
# 10       01DPR0023G2     2     B           0
# 11       01DPR0023G2     4     A           0
# 12       01DPR0023G2     3     B           0
# 13       01DPR0023G2     3     A           0
# 14       01DPR0023G2     1     A           0
# 15       01DPR0023G2     4     B           0
# 16       01DPR0023G2     2     A           0
# 17       01DPR0023G2     1     B           0
# 18       01DPR0024F2     6     A           0
# 19       01DPR0024F2     5     B           0
# ...

# %%
# Carpeta Inmueble (3 archivos)
# Carga de datos
## Por el momento todos los archivos no se encuentran disponibles para descargar

# %%
#pd.read_csv("/Volumes/PCT/CEMABE/Inmueble/TR_EXP_CUES_CONAFE_INM_CT.txt", header=0, sep='|', encoding='latin-1')
# Error en linea 965

# %%
pd.read_csv("/Volumes/PCT/CEMABE/Inmueble/TR_EXP_CUES_INMUEBLE.txt", header=0, sep='|', encoding='latin-1')
# Out:
#         ENT  MUN  LOC  AGEB  MZA  ID_INM  P2A  \
# 0         2    4    1  2876   23    1914    1
# 1         2    4    1  2880  103    1915    1
# 2         2    4    1  3677    5    1916    1
# 3         2    4    1  3677    9    1917    1
# 4         2    4    1  3677   23    1918    7
# 5         2    4    1  3681   17    1919    1
# 6         2    4    1  3681   25    1920    1
# 7         2    4    1  3817    9    1921    1
# 8         2    4    1  1191   39    1922    2
# 9         2    4    1  1191   39    1923    1
# 10        2    4    1  1191   39    1924    1
# 11        2    4    1  2467   18    1925    1
# 12        2    4    1  1806   57    1926    2
# 13        2    4    1  1806   57    1927    1
# 14        2    4    1  1806   50    1928    1
# 15        2    4    1  1806   65    1929    1
# 16        2    4    1  6525   19    1763    1
# 17        2    4    1  3821   59    1765    1
# 18        2    4    1  4266    1    1766    5
# ...

# %%
pd.read_csv("/Volumes/PCT/CEMABE/Inmueble/TR_EXP_INMUEBLE_CONTROL.txt", header=0, sep='|', encoding='latin-1', low_memory=False)
# Out:
#         ID_INM  ENT_CARGA  MUN_CARGA  LOC_CARGA AGEB_CARGA  MZA_CARGA  \
# 0       209238         15        109         25       0188         24
# 1       209239         15        109         25       181A         20
# 2       209240         15        109         68       0667         99
# 3       209241         15        109         68       0864         11
# 4       209242         15        109         68       0864         12
# 5       209243         15        109         68       0864         12
# 6       209244         15        109         68       0864         12
# 7       209665         15         33        207       2678        800
# 8       209666         15         33        207       2678        800
# 9       209667         15         33        207       2678        800
# 10      209668         15         33        207       2678        800
# 11      209669         15         20          1       0175          9
# ...
